# %% [markdown]
# <img src='graphics/3D.jpeg'>
# <img src='graphics/spacer.png'>
#
# <center><font style="font-size:40px;">3D Plotting with Matplotlib </font></center>
# <center>Prepared and coded by Ben P. Meredith, Ed.D.</center>

# %% [markdown]
# # A Basic 3D Line Plot
#
# 3D plotting in Matplotlib starts by enabling the utility toolkit. We can enable this toolkit by importing the mplot3d library, which comes with your standard Matplotlib installation via pip. Just be sure that your Matplotlib version is over 1.0.
#
# Once this sub-module is imported, 3D plots can be created by passing the keyword projection="3d" to any of the regular axes creation functions in Matplotlib

# %%
from mpl_toolkits import mplot3d

import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 10))
ax = plt.axes(projection="3d")

# Add some labels and titles
ax.set_xlabel('x', color='red', fontsize=16)
ax.set_ylabel('y', color='red', fontsize=16)
ax.set_zlabel('z', color='red', fontsize=16)


plt.show()

# %% [markdown]
# Now that our axes are created we can start plotting in 3D. The 3D plotting functions are quite intuitive: instead of just scatter we call scatter3D , and instead of passing only x and y data, we pass over x, y, and z. All of the other function settings such as colour and line type remain the same as with the 2D plotting functions.
#
# Here’s an example of plotting a 3D line and 3D points.

# %%
# Common Matplotlib initialization 
fig = plt.figure(figsize=(15, 12))# we set the size of the graph in this visualization
ax = plt.axes(projection="3d")

# Generate our data that we will use to plot our line
z_line = np.linspace(0, 15, 1000)
x_line = np.cos(z_line)
y_line = np.sin(z_line)

# The actual line plot
ax.plot3D(x_line, y_line, z_line, 'gray')

# Add some labels and titles
ax.set_xlabel('X Axis', color='red', fontsize=16)
ax.set_ylabel('Y Axis', color='red', fontsize=16)
ax.set_zlabel('Z Axis', color='red', fontsize=16)
ax.set_title('line', color='red', fontsize=16);

# Rotate the angle of the plot
ax.view_init(22, 55)

plt.show()

# %% [markdown]
# # Surface Plots
# Surface plots can be great for visualising the relationships among 3 variables across the entire 3D landscape. They give a full structure and view as to how the value of each variable changes across the axes of the 2 others.
# Constructing a surface plot in Matplotlib is a 3-step process.
#
# (1) First we need to generate the actual points that will make up the surface plot. Now, generating all the points of the 3D surface is impossible since there are an infinite number of them! So instead, we’ll generate just enough to be able to estimate the surface and then extrapolate the rest of the points. We’ll define the x and y points and then compute the z points using a function.

# %%
# Common Matplotlib initalization
fig = plt.figure()
ax = plt.axes(projection="3d")

# Generate some data for the next examples
def z_function(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = z_function(X, Y)

# %% [markdown]
# (2) The second step is to plot a wire-frame — this is our estimate of the surface.

# %%
# Common Matplotlib graphing initialization
fig = plt.figure(figsize=(14,10))
ax = plt.axes(projection="3d")

# Plot the data we generated above
ax.plot_wireframe(X, Y, Z, color='green')

# Rotate the angle of the plot
ax.view_init(45, 35)

# Add some labels and titles
ax.set_xlabel('x', color='red', fontsize=16)
ax.set_ylabel('y', color='red', fontsize=16)
ax.set_zlabel('z', color='red', fontsize=16)
ax.set_title('wireframe', color='red', fontsize=16);


plt.show()

# %% [markdown]
# (3) Finally, we’ll project our surface onto our wire-frame estimate and extrapolate all of the points.

# %%
fig = plt.figure(figsize=(12, 10))
ax = plt.axes(projection='3d')

# Plot a surface graph
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='winter', edgecolor='none')

# Rotate the angle of the plot
ax.view_init(45, 55)

# Add some labels and titles
ax.set_xlabel('X Axis', color='red', fontsize=16)
ax.set_ylabel('Y Axis', color='red', fontsize=16)
ax.set_zlabel('Z Axis', color='red', fontsize=16)
ax.set_title('surface', color='red', fontsize=16);

# Rotate the angle of the plot
ax.view_init(45, 35)

plt.show()

# %% [markdown]
# # 3D Bar Plots
# Bar plots are used quite frequently in data visualisation projects since they’re able to convey information, usually some type of comparison, in a simple and intuitive way. The beauty of 3D bar plots is that they maintain the simplicity of 2D bar plots while extending their capacity to represent comparative information.
# Each bar in a bar plot always needs 2 things: a position and a size. With 3D bar plots, we’re going to supply that information for all three variables x, y, z.
#
# We’ll select the z axis to encode the height of each bar; therefore, each bar will start at z = 0 and have a size that is proportional to the value we are trying to visualise. The x and y positions will represent the coordinates of the bar across the 2D plane of z = 0. We’ll set the x and y size of each bar to a value of 1 so that all the bars have the same shape.
#
# Check out the code and 3D plots below for an example!

# %%
import random

# Common Matplotlib initialization
fig = plt.figure(figsize=(12,10))
ax = plt.axes(projection="3d")

# Generate random data to plot
num_bars = 5
x_pos = random.sample(range(20), num_bars)
y_pos = random.sample(range(20), num_bars)
z_pos = [0] * num_bars
x_size = np.ones(num_bars)
y_size = np.ones(num_bars)
z_size = random.sample(range(20), num_bars)

# Plot the data
ax.bar3d(x_pos, y_pos, z_pos, x_size, y_size, z_size, color='aqua')

# Add some labels and titles
ax.set_xlabel('X Axis', color='red', fontsize=16)
ax.set_ylabel('Y Axis', color='red', fontsize=16)
ax.set_zlabel('Z Axis', color='red', fontsize=16)
ax.set_title('bar', color='red', fontsize=16);

# Rotate the angle of the plot
ax.view_init(22, 35)
    
    
plt.show()

# %% [markdown]
# # Scatter Plots

# %%
# Generate some data
def f(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

theta = 2 * np.pi * np.random.random(1000)
r = 6 * np.random.random(1000)
x = np.ravel(r * np.sin(theta))
y = np.ravel(r * np.cos(theta))
z = f(x, y)

# Common Matplotlib initialization
fig = plt.figure(figsize=(12,10))
ax = plt.axes(projection="3d")

# The plot of the data
ax.scatter(x, y, z, c=z, cmap='viridis', linewidth=0.5);

# Add some labels and titles
ax.set_xlabel('X Axis', color='red', fontsize=16)
ax.set_ylabel('Y Axis', color='red', fontsize=16)
ax.set_zlabel('Z Axis', color='red', fontsize=16)
ax.set_title('scatter', color='red', fontsize=16);

# Rotate the angle of the plot
ax.view_init(22, 35)
    
    
plt.show()

# %% [markdown]
# # Combining 3D Line and Scatter Plots

# %%
# Common Matplotlib initialization 
fig = plt.figure(figsize=(15, 12))# we set the size of the graph in this visualization
ax = plt.axes(projection="3d")

# Generate our data that we will use to plot our line
z_line = np.linspace(0, 15, 1000)
x_line = np.cos(z_line)
y_line = np.sin(z_line)

# The actual line plot
ax.plot3D(x_line, y_line, z_line, 'gray')

# Generate our data that we will use for the scatter points
z_points = 15 * np.random.random(100)
x_points = np.cos(z_points) + 0.1 * np.random.randn(100)
y_points = np.sin(z_points) + 0.1 * np.random.randn(100)

# The actual scatter plot
ax.scatter3D(x_points, y_points, z_points, c=z_points, cmap='hsv');

# Add some labels and titles
ax.set_xlabel('X Axis', color='red', fontsize=16)
ax.set_ylabel('Y Axis', color='red', fontsize=16)
ax.set_zlabel('Z Axis', color='red', fontsize=16)
ax.set_title('line & scatter', color='red', fontsize=16);

# Rotate the angle of the plot
ax.view_init(22, 35)

plt.show()

# %% [markdown]
# # Plotting a Mobius Strip

# %%
# Generate some data
theta = np.linspace(0, 2 * np.pi, 30)
w = np.linspace(-0.25, 0.25, 8)
w, theta = np.meshgrid(w, theta)
phi = 0.5 * theta

# radius in x-y plane
r = 1 + w * np.cos(phi)

# x, y, and z paths
x = np.ravel(r * np.cos(theta))
y = np.ravel(r * np.sin(theta))
z = np.ravel(w * np.sin(phi))

# %%
# Load some necessary libraries
from matplotlib.tri import Triangulation
tri = Triangulation(np.ravel(w), np.ravel(theta))

# Common Matplotlib initializations
fig = plt.figure(figsize=(12,10))
ax = plt.axes(projection='3d')

# Plot the Data
ax.plot_trisurf(x, y, z, triangles=tri.triangles,cmap='viridis', linewidths=0.2);

# Set some axes limiters
ax.set_xlim(-1, 1); ax.set_ylim(-1, 1); ax.set_zlim(-1, 1);

# Add some labels and titles
ax.set_xlabel('X Axis', color='red', fontsize=16)
ax.set_ylabel('Y Axis', color='red', fontsize=16)
ax.set_zlabel('Z Axis', color='red', fontsize=16)
ax.set_title('Mobius Strip Plot', color='red', fontsize=16);

# Rotate the angle of the plot
ax.view_init(30, 65)

plt.show()

# %% [markdown]
# # Exercise
#
# In this exercise, we will be using the `open_high_close.csv` file located in the `data` folder of this lesson. This dataset is an extract of opening, high, low and closing prices of stocks between 2009-2018. It is a very large dataset with over 600,000 observations/rows, but we will not be using all of the rows. I have taken the liberty to eliminate some columns from the orginial dataset so that we are left with three columns (open, high, closed).
#
# You will have several tasks to perform.
# 1. Import the entire csv file
# 1. Reduce the DataFrame to 1000 random sample rows
# 1. Check the shape of your working DataFrame to insure that it is (1000, 3) in size
# 1. Plot the values as follows:
# > 1. x = the opening stock price
# > 1. y = the closing stock price
# > 1. z = the highest stock price
# 1. Make the labels of the plot red
# 1. Set the optimal angle of the plot to be able to best read the data

# %%
import pandas as pd

df = pd.read_csv('data/open_high_close.csv', index_col = 0)

df = df.sample(1000)

df.shape
# Out:
# (1000, 3)

# %%
# Plot the x, y and z axis in a 3D scatter plot

# Common Matplotlib initializations
fig = plt.figure(figsize=(12,10))
ax = plt.axes(projection='3d')

# Assign values
x = df.open
y = df.close
z = df.high

# The actual scatter plot
ax.scatter3D(x, y, z)

# Add some labels and titles
ax.set_xlabel('Open Value', color='red', fontsize=16)
ax.set_ylabel('Close Value', color='red', fontsize=16)
ax.set_zlabel('High Value', color='red', fontsize=16)
ax.set_title('Open, High, Close', color='red', fontsize=16);

# Rotate the angle of the plot
ax.view_init(20, 700)

plt.show()

# %% [markdown]
# ## Observations
#
# From this plot, what are our observations?
